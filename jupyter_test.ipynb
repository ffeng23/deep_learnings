# %% [markdown]
# # Testing Jupyter notebook
#
# Just want to see how it works in vs code.
#
# Of course, we need to install jupyter lab and python in the system as dependencies.

# %%
# Python
print("Hello world!!")
# Out:
# Hello world!!

# %% [markdown]
# ## Next we want to test plotting.
#
# Try sns for this test.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[1,2,3]
y=[4,5,6]

plt.figure(figsize=(3,3))
sns.scatterplot(x=x, y=y)
plt.show()
